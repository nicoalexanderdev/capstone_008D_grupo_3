# %%
import cv2
import torch
import urllib.request

import matplotlib.pyplot as plt

# url, filename = ("https://github.com/pytorch/hub/raw/master/images/dog.jpg", "dog.jpg")
# urllib.request.urlretrieve(url, filename)

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device
# Out:
# device(type='cuda')

# %%
#model_type = "DPT_Large"     # MiDaS v3 - Large     (highest accuracy, slowest inference speed)
model_type = "DPT_Hybrid"   # MiDaS v3 - Hybrid    (medium accuracy, medium inference speed)
#model_type = "MiDaS_small"  # MiDaS v2.1 - Small   (lowest accuracy, highest inference speed)

midas = torch.hub.load("intel-isl/MiDaS", model_type)
# Out:
# Using cache found in C:\Users\osesn/.cache\torch\hub\intel-isl_MiDaS_master
# C:\Users\osesn\Documents\GitHub\capstone_008D_grupo_3\App MetroSence\modelos_metrosence\mod-venv\Lib\site-packages\timm\models\_factory.py:138: UserWarning: Mapping deprecated model name vit_base_resnet50_384 to current vit_base_r50_s16_384.orig_in21k_ft_in1k.
#   model = create_fn(

# %%
midas.to(device)
midas.eval()
# Out:
# DPTDepthModel(
#   (pretrained): Module(
#     (model): VisionTransformer(
#       (patch_embed): HybridEmbed(
#         (backbone): ResNetV2(
#           (stem): Sequential(
#             (conv): StdConv2dSame(3, 64, kernel_size=(7, 7), stride=(2, 2), bias=False)
#             (norm): GroupNormAct(
#               32, 64, eps=1e-05, affine=True
#               (drop): Identity()
#               (act): ReLU(inplace=True)
#             )
#             (pool): MaxPool2dSame(kernel_size=(3, 3), stride=(2, 2), padding=(0, 0), dilation=(1, 1), ceil_mode=False)
#           )
#           (stages): Sequential(
#             (0): ResNetStage(
#               (blocks): Sequential(
#                 (0): Bottleneck(
#                   (downsample): DownsampleConv(
#                     (conv): StdConv2dSame(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (norm): GroupNormAct(
#                       32, 256, eps=1e-05, affine=True
# ...

# %%
midas_transforms = torch.hub.load("intel-isl/MiDaS", "transforms")

if model_type == "DPT_Large" or model_type == "DPT_Hybrid":
    transform = midas_transforms.dpt_transform
else:
    transform = midas_transforms.small_transform
# Out:
# Using cache found in C:\Users\osesn/.cache\torch\hub\intel-isl_MiDaS_master

# %%
filename = "0-023635201142181428210_jpg.rf.81296155e2880a0482f9eb27d8fcd696.jpg"

# %%
img = cv2.imread(filename)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

input_batch = transform(img).to(device)

# %%
with torch.no_grad():
    prediction = midas(input_batch)

    prediction = torch.nn.functional.interpolate(
        prediction.unsqueeze(1),
        size=img.shape[:2],
        mode="bicubic",
        align_corners=False,
    ).squeeze()

output = prediction.cpu().numpy()

# %%
plt.imshow(output)
#plt.show()

# %%
import cv2
import torch
import numpy as np
import time

# ============ Config ============
# Elige el modelo: "DPT_Hybrid", "DPT_Large", o "MiDaS_small"
model_type = "DPT_Hybrid"  # cámbialo a "MiDaS_small" si va lento en CPU
cam_index = 0              # índice de la cámara (0 suele ser la webcam integrada)
show_width = 960           # ancho de visualización (resize para pantalla)
roi_frac = 0.30            # tamaño del ROI central (30% del lado más corto)
D_REF = 1.00               # distancia de referencia en metros para calibrar
# ===============================

# Selección de dispositivo
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print("Device:", device)

# Carga de modelo y transform
midas = torch.hub.load("intel-isl/MiDaS", model_type)
midas.to(device)
midas.eval()
midas_transforms = torch.hub.load("intel-isl/MiDaS", "transforms")
if model_type in ["DPT_Large", "DPT_Hybrid"]:
    transform = midas_transforms.dpt_transform
else:
    transform = midas_transforms.small_transform

# Cámara
cap = cv2.VideoCapture(cam_index)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

if not cap.isOpened():
    raise RuntimeError("No se pudo abrir la cámara. Verifica cam_index o permisos.")

# Utilidades
def median_depth_in_roi(depth_rel, frac=0.3):
    """Retorna la mediana en un ROI central (con recorte de outliers 5-95%)."""
    h, w = depth_rel.shape
    side = int(min(h, w) * frac)
    y1 = h // 2 - side // 2
    x1 = w // 2 - side // 2
    roi = depth_rel[y1:y1+side, x1:x1+side]
    roi = roi[np.isfinite(roi)]
    if roi.size == 0:
        return np.nan, (x1, y1, side, side)
    # recorte de outliers
    lo, hi = np.percentile(roi, [5, 95])
    roi = roi[(roi >= lo) & (roi <= hi)]
    if roi.size == 0:
        return np.nan, (x1, y1, side, side)
    return np.median(roi), (x1, y1, side, side)

def colorize_depth(depth_rel):
    """Normaliza a 0..1 por frame y aplica colormap (magma)."""
    d = depth_rel.copy()
    d = d[np.isfinite(d)]
    if d.size == 0:
        return None
    mn, mx = np.percentile(d, [5, 95])  # robusto
    if mx - mn < 1e-6:
        return None
    norm = (depth_rel - mn) / (mx - mn)
    norm = np.clip(norm, 0, 1)
    norm_u8 = (norm * 255).astype(np.uint8)
    colored = cv2.applyColorMap(norm_u8, cv2.COLORMAP_MAGMA)
    return colored

# Calibración: dist_m ≈ k * depth_rel
k_scale = None
calibrated = False

prev_time = time.time()
fps = 0.0

print("Controles: q=salir, c=calibrar, r=reset, [ / ] = D_REF -/+ 0.1 m")

try:
    while True:
        ret, frame_bgr = cap.read()
        if not ret:
            print("Frame no capturado.")
            break

        # Resize para visualización consistente (mantener aspecto)
        h0, w0 = frame_bgr.shape[:2]
        scale = show_width / w0
        show_h = int(h0 * scale)
        frame_bgr_show = cv2.resize(frame_bgr, (show_width, show_h), interpolation=cv2.INTER_LINEAR)

        # Preprocesamiento MiDaS: BGR -> RGB
        frame_rgb = cv2.cvtColor(frame_bgr_show, cv2.COLOR_BGR2RGB)
        input_batch = transform(frame_rgb).to(device)

        # Inferencia
        with torch.no_grad():
            pred = midas(input_batch)  # [1,H',W'] o [1,384,384] según modelo
            if pred.dim() == 3:
                pred = pred.unsqueeze(1)  # [1,1,H',W']
            # Reescalar al tamaño del frame mostrado
            pred_up = torch.nn.functional.interpolate(
                pred, size=frame_rgb.shape[:2], mode="bicubic", align_corners=False
            ).squeeze(0).squeeze(0)  # [H,W]

        depth_rel = pred_up.detach().cpu().numpy()

        # Mediana en ROI central
        z_rel_med, (x1, y1, side) = (np.nan, (0,0,0))
        z_rel_med, (x1, y1, side, side) = median_depth_in_roi(depth_rel, frac=roi_frac)

        # Estimación métrica si calibrado
        dist_est_m = np.nan
        if calibrated and k_scale is not None and np.isfinite(z_rel_med):
            dist_est_m = float(k_scale * z_rel_med)

        # Colorizar profundidad
        depth_color = colorize_depth(depth_rel)
        if depth_color is None:
            depth_vis = frame_bgr_show.copy()
        else:
            # combinar: cuadro del ROI y texto
            depth_vis = depth_color

        # FPS
        now = time.time()
        fps = 0.9 * fps + 0.1 * (1.0 / max(now - prev_time, 1e-6))
        prev_time = now

        # Dibuja ROI y texto
        cv2.rectangle(depth_vis, (x1, y1), (x1+side, y1+side), (0, 255, 0), 2)
        y_text = 24
        cv2.putText(depth_vis, f"FPS: {fps:.1f}", (10, y_text), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,255), 2); y_text += 24
        cv2.putText(depth_vis, f"Model: {model_type}", (10, y_text), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 1); y_text += 22
        status = "ON" if calibrated else "OFF"
        cv2.putText(depth_vis, f"Calibrated: {status} | D_REF: {D_REF:.2f} m", (10, y_text), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 1); y_text += 22

        if np.isfinite(dist_est_m):
            cv2.putText(depth_vis, f"Dist(ROI) ~ {dist_est_m:.2f} m", (10, y_text), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,255), 2); y_text += 26
        else:
            if np.isfinite(z_rel_med):
                cv2.putText(depth_vis, f"Depth_rel(ROI): {z_rel_med:.3f} (sin escala)", (10, y_text), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 1); y_text += 22
            else:
                cv2.putText(depth_vis, "Depth_rel(ROI): NaN", (10, y_text), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 1); y_text += 22

        cv2.putText(depth_vis, "q=salir | c=calibrar | r=reset | [ / ] D_REF -/+", (10, show_h - 12), cv2.FONT_HERSHEY_SIMPLEX, 0.55, (255,255,255), 1)

        cv2.imshow("MiDaS depth (estimada)", depth_vis)

        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('c'):
            # Calibración: asume que el plano del ROI está a D_REF metros
            if np.isfinite(z_rel_med) and z_rel_med > 0:
                k_scale = D_REF / z_rel_med
                calibrated = True
                print(f"[Calibrado] k_scale = {k_scale:.6f} (D_REF={D_REF:.2f} m, z_rel_med={z_rel_med:.6f})")
            else:
                print("No se pudo calibrar: z_rel_med inválido (mueve la cámara o ajusta ROI).")
        elif key == ord('r'):
            calibrated = False
            k_scale = None
            print("[Reset] Calibración borrada.")
        elif key == ord('['):
            D_REF = max(0.1, D_REF - 0.1)
        elif key == ord(']'):
            D_REF = D_REF + 0.1

finally:
    cap.release()
    cv2.destroyAllWindows()
# Out:
# Device: cuda
# Using cache found in C:\Users\osesn/.cache\torch\hub\intel-isl_MiDaS_master
# Loading weights:  None
# Using cache found in C:\Users\osesn/.cache\torch\hub\rwightman_gen-efficientnet-pytorch_master
# Using cache found in C:\Users\osesn/.cache\torch\hub\intel-isl_MiDaS_master
# Controles: q=salir, c=calibrar, r=reset, [ / ] = D_REF -/+ 0.1 m
# [Calibrado] k_scale = 0.001334 (D_REF=1.00 m, z_rel_med=749.459473)
# [Calibrado] k_scale = 0.001284 (D_REF=1.00 m, z_rel_med=778.742004)
# [Calibrado] k_scale = 0.001355 (D_REF=1.00 m, z_rel_med=737.845703)
